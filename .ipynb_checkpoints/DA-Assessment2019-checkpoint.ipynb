# %% [markdown]
# # Tips Dataset Analysis
#
#
# The aim of this project is to research the tips dataset @ Freha
#
# One food server recorded information about each tip he received over a period of a few months working in one restaurant. He collected several variables:
# - tip in dollars
# - bill in dollars
# - sex of the bill payer
# - whether there were smokers in the party
# - day of the week
# - time of day
# - size of the party.
#
# In all he recorded 244 tips. The data was reported in a collection of case studies for business statistics (Bryant & Smith 1995).
#
# Tips dataset is part of the seaborn package. This notebook contains
#
# 1. Analysis of tips dataset
#       - Uses descriptive statistics and plots to describe the tips dataset.
# 2. Regression
#       - Relationship between the totalbill and tip amount
# 3. Analysis of the relationship between the variables within the dataset.

# %% [markdown]
# ## Import Libraries

# %%
# import seaborn 
import seaborn as sns
# Seaborn is a library for making statistical graphics in Python
#It is built on top of matplotlib and closely integrated with pandas data structures.

# %matplotlib inline 
# https://stackoverflow.com/a/43028105 to fix the graph 
# import matplotlib
import matplotlib.pyplot as plt
#Matplotlib is a Python 2D plotting library 
#which produces publication quality figures in a variety of hardcopy formats and interactive environments across platforms.

# import pandas
import pandas as pd

# sklearn packages we need for regression import later in regression part to keep that altogather
#from sklearn.model_selection import train_test_split 
#from sklearn.linear_model import LinearRegression

# %% [markdown]
# ## Load the dataset

# %%
# load tips dataset
# it part of the seaborn package
tips = sns.load_dataset("tips")

# %% [markdown]
# # 1. Analysis of Tips Dataset
# ## Exploratory Data Analysis(EDA)
# EDA is an analysis approach that focuses on identifying general patterns in the data and to find previously unknown relationships.

# %% [markdown]
# ### Number of rows and columns in tips dataset

# %%
# number of rows and columns in dataset
tips.shape
# Out:
# (244, 7)

# %% [markdown]
# There are 244 rows and 7 columns in tips data set

# %% [markdown]
# ### Columns in tips dataset

# %%
# columns in tips dataset
tips.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
#columns and datatype of columns
tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
# total_bill    244 non-null float64
# tip           244 non-null float64
# sex           244 non-null category
# smoker        244 non-null category
# day           244 non-null category
# time          244 non-null category
# size          244 non-null int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.2 KB

# %%
# to check if there is any null value
tips.isnull().sum()
# Out:
# total_bill    0
# tip           0
# sex           0
# smoker        0
# day           0
# time          0
# size          0
# dtype: int64

# %%
#Look at the whole dataset
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# 5         25.29  4.71    Male     No   Sun  Dinner     4
# 6          8.77  2.00    Male     No   Sun  Dinner     2
# 7         26.88  3.12    Male     No   Sun  Dinner     4
# 8         15.04  1.96    Male     No   Sun  Dinner     2
# 9         14.78  3.23    Male     No   Sun  Dinner     2
# 10        10.27  1.71    Male     No   Sun  Dinner     2
# 11        35.26  5.00  Female     No   Sun  Dinner     4
# 12        15.42  1.57    Male     No   Sun  Dinner     2
# 13        18.43  3.00    Male     No   Sun  Dinner     4
# 14        14.83  3.02  Female     No   Sun  Dinner     2
# 15        21.58  3.92    Male     No   Sun  Dinner     2
# 16        10.33  1.67  Female     No   Sun  Dinner     3
# 17        16.29  3.71    Male     No   Sun  Dinner     3
# 18        16.97  3.50  Female     No   Sun  Dinner     3
# 19        20.65  3.35    Male     No   Sat  Dinner     3
# 20        17.92  4.08    Male     No   Sat  Dinner     2
# 21        20.29  2.75  Female     No   Sat  Dinner     2
# 22        15.77  2.23  Female     No   Sat  Dinner     2
# 23        39.42  7.58    Male     No   Sat  Dinner     4
# 24        19.82  3.18    Male     No   Sat  Dinner     2
# 25        17.81  2.34    Male     No   Sat  Dinner     4
# 26        13.37  2.00    Male     No   Sat  Dinner     2
# 27        12.69  2.00    Male     No   Sat  Dinner     2
# 28        21.70  4.30    Male     No   Sat  Dinner     2
# 29        19.65  3.00  Female     No   Sat  Dinner     2
# ..          ...   ...     ...    ...   ...     ...   ...
# 214       28.17  6.50  Female    Yes   Sat  Dinner     3
# 215       12.90  1.10  Female    Yes   Sat  Dinner     2
# 216       28.15  3.00    Male    Yes   Sat  Dinner     5
# 217       11.59  1.50    Male    Yes   Sat  Dinner     2
# 218        7.74  1.44    Male    Yes   Sat  Dinner     2
# 219       30.14  3.09  Female    Yes   Sat  Dinner     4
# 220       12.16  2.20    Male    Yes   Fri   Lunch     2
# 221       13.42  3.48  Female    Yes   Fri   Lunch     2
# 222        8.58  1.92    Male    Yes   Fri   Lunch     1
# 223       15.98  3.00  Female     No   Fri   Lunch     3
# 224       13.42  1.58    Male    Yes   Fri   Lunch     2
# 225       16.27  2.50  Female    Yes   Fri   Lunch     2
# 226       10.09  2.00  Female    Yes   Fri   Lunch     2
# 227       20.45  3.00    Male     No   Sat  Dinner     4
# 228       13.28  2.72    Male     No   Sat  Dinner     2
# 229       22.12  2.88  Female    Yes   Sat  Dinner     2
# 230       24.01  2.00    Male    Yes   Sat  Dinner     4
# 231       15.69  3.00    Male    Yes   Sat  Dinner     3
# 232       11.61  3.39    Male     No   Sat  Dinner     2
# 233       10.77  1.47    Male     No   Sat  Dinner     2
# 234       15.53  3.00    Male    Yes   Sat  Dinner     2
# 235       10.07  1.25    Male     No   Sat  Dinner     2
# 236       12.60  1.00    Male    Yes   Sat  Dinner     2
# 237       32.83  1.17    Male    Yes   Sat  Dinner     2
# 238       35.83  4.67  Female     No   Sat  Dinner     3
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# Tips dataset contains tips data from different customers females and males smokers and non smokers from days Thursday to Sunday, dinner or lunch and from different tables size
#
# ####  Columns containing categorical data
#  - sex
#  - smoker
#  - day
#  - time
#
# ####  Columns containing numerical data
#  - total_bill
#  - tip
#  - size

# %%
# first five rows of dataset
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
#last 5 rows of dataset
tips.tail()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2

# %% [markdown]
# ### Values in columns day, time, smoker and size

# %%
# days the resturant opens or the days data is recorded for
print("Day : ",tips['day'].unique())
# Out:
# Day :  [Sun, Sat, Thur, Fri]
# Categories (4, object): [Sun, Sat, Thur, Fri]

# %%
#unique Time value in time column
print("Time : ",tips['time'].unique())
# Out:
# Time :  [Dinner, Lunch]
# Categories (2, object): [Dinner, Lunch]

# %%
tips['smoker'].unique()#smoker variable values
# Out:
# [No, Yes]
# Categories (2, object): [No, Yes]

# %%
tips['size'].unique()#size variable values
# Out:
# array([2, 3, 4, 1, 6, 5], dtype=int64)

# %% [markdown]
# ## Descriptive Statistics
# ### Statistical Summary of tips dataset

# %%
# common statistics of numerical data columns
tips.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %% [markdown]
# For numeric data, the describe result’s index will include count, mean, std, min, max as well as lower, 50 and upper percentiles.
#  - **count:** number of observations in a column
#  - **mean:** Mean of the values in a column.
#  - **std:** Standard deviation of observations
#  - **min:** minimum value of all numeric values in a column
#  - **25% ,50%, 75%:** Given percentile values (quantile 1, 2 and 3 respectively)
#  - **max:** maximum value of all numeric values in a column

# %%
# maximum bill & minimum bill
print("Maximum bill =",tips['total_bill'].max(),"  Minimum bill = " ,tips['total_bill'].min())
# Out:
# Maximum bill = 50.81   Minimum bill =  3.07

# %%
# maximum tip & minimum tip
print("Maximum Tip =",tips['tip'].max(),"  Minimum Tip = " ,tips['tip'].min())
# Out:
# Maximum Tip = 10.0   Minimum Tip =  1.0

# %%
#average total_bill,tip and size of group
tips.mean().round(2)
# Out:
# total_bill    19.79
# tip            3.00
# size           2.57
# dtype: float64

# %% [markdown]
# ### Number of males and females paid the bill

# %%
gender= tips['sex'].value_counts()# number of males and females paid the bill
print("Number of Males:  ",gender['Male'])
print("Number of Females :  ", gender['Female'])
# Out:
# Number of Males:   157
# Number of Females :   87

# %%
# no of males and non females paid the bill (countplot)
#plt.rcParams.update(plt.rcParamsDefault)
#%matplotlib inline
#import matplotlib as mpl
#inline_rc = dict(mpl.rcParams)
# source: https://stackoverflow.com/a/26413529 to restore default graph style
g = sns.countplot(x='sex',data=tips)
plt.show()

# %% [markdown]
# The number of times male pay the bill is greater than females who paid bill.

# %% [markdown]
# ### Number  of smokers and non smokers

# %%
# Number of smokers and non smokers groups
smoke=tips['smoker'].value_counts()
print("Smokers :  ",smoke['Yes'])
print("Non Smokers :  ",smoke['No'])
# Out:
# Smokers :   93
# Non Smokers :   151

# %% [markdown]
# This number of smokers and non smokers are the count of the yes and no entries in the smoker column. It is not telling the number of smoker and non smoker customers. in case of 1 person group size it is clear that entry is for that person but in group of 2 and more this yes only mean that, the group was in smoking area or may be one of the group member was smoker

# %%
# no of smokers and non smokers countplot
sns.countplot(x='smoker',data=tips)
plt.show()

# %% [markdown]
# The number of smokers in tips data set are less than non smokers or the waiter served more non smoker groups

# %% [markdown]
# ### Number of males and the number of females that paid the bill each day

# %%
print(tips.groupby(by=['sex', 'day'])['day'].count())
# countplot of number of males and numder females paid the bill on each day 
sns.countplot(x='sex',data=tips,hue='day')
plt.show()
# Out:
# sex     day
# Male    Thur    30
#         Fri     10
#         Sat     59
#         Sun     58
# Female  Thur    32
#         Fri      9
#         Sat     28
#         Sun     18
# Name: day, dtype: int64

# %% [markdown]
# - on weekend males paid mostly

# %% [markdown]
# ### Number of smokers and non smokers on each day

# %%
 # number of smokers and nonsmokers on each day
#source: https://www.codementor.io/tips/3847022612/counting-number-of-occurrences-on-pandas-dataframe-columns
print(tips.groupby(by=['smoker', 'day'])['day'].count())
# count plot to visulise the data
sns.countplot(x='smoker',data=tips, hue='day')
plt.show()
# Out:
# smoker  day
# Yes     Thur    17
#         Fri     15
#         Sat     42
#         Sun     19
# No      Thur    45
#         Fri      4
#         Sat     45
#         Sun     57
# Name: day, dtype: int64

# %% [markdown]
# - On Friday the number of smokers are  more than non smokers
# - on Saturday the number of smokers and non smoker are nearly equal
# - On Thursday and Sunday the number of non smoker parties is higher than smokers

# %% [markdown]
# ### The number of males and the number of females that paid the bill at lunch and dinner

# %%
# countplot of number of males and females paid the bill at lunch and dinner
print(tips.groupby(by=['sex', 'time'])['time'].count())
sns.countplot(x='sex',data=tips,hue='time')
plt.show()
# Out:
# sex     time
# Male    Lunch      33
#         Dinner    124
# Female  Lunch      35
#         Dinner     52
# Name: time, dtype: int64

# %% [markdown]
# -  Lunch time the number of males and females who paid bill is nealy equal
# -  Dinner time the higher proportion of bills are paid by males

# %% [markdown]
# ### Number of smokers and non smokers at lunch and dinner

# %%
# number of smokers and nonsmokers at lunch and dinner
print(tips.groupby(by=['smoker', 'time'])['time'].count())
sns.countplot(x='smoker',data=tips, hue='time')# countplot
plt.show()
# Out:
# smoker  time
# Yes     Lunch      23
#         Dinner     70
# No      Lunch      45
#         Dinner    106
# Name: time, dtype: int64

# %% [markdown]
# - The number of smokers on both times (lunch and dinner) are less than non smokers

# %% [markdown]
# ### Group size of smokers and non smokers

# %%
# number of smokers and  non smokers (group size)
print(tips.groupby(by=['smoker', 'size'])['size'].count())
sns.countplot(x='smoker',data=tips, hue='size')# countplot 
plt.show()
# Out:
# smoker  size
# Yes     1        2
#         2       66
#         3       12
#         4       11
#         5        2
# No      1        2
#         2       90
#         3       26
#         4       26
#         5        3
#         6        4
# Name: size, dtype: int64

# %% [markdown]
# - the waiter mostly served the smoker and nonsmoker in group size 2.

# %% [markdown]
# ### The group size of males and  females that paid the bill

# %%
# countplot of number of males and  females paid the bill (group size) 
print(tips.groupby(by=['sex', 'size'])['size'].count())
sns.countplot(x='sex',data=tips,hue='size')
plt.show()
# Out:
# sex     size
# Male    1        1
#         2       98
#         3       24
#         4       28
#         5        4
#         6        2
# Female  1        3
#         2       58
#         3       14
#         4        9
#         5        1
#         6        2
# Name: size, dtype: int64

# %% [markdown]
# - For both male and females who paid the bill, mostly the party size was 2.

# %% [markdown]
# ### Distribution of size data

# %%
sns.distplot(tips['size'])
# Out:
# C:\Users\Admin2\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# Most entries in size column of dataset are 2

# %% [markdown]
# ### Total_bill data distribution

# %%
sns.distplot(tips['total_bill'])

# %% [markdown]
# Most bills are in range 10 to 25

# %% [markdown]
# ## Tip data distribution

# %%
sns.distplot(tips['tip'], color='red')

# %% [markdown]
# Most tips are between 2 to 4

# %% [markdown]
# ### The sum of total bill and tips for each day

# %%
tips.groupby(["day"]).sum()# total bill and tips sum for each day
# Out:
#       total_bill     tip  size
# day
# Thur     1096.33  171.83   152
# Fri       325.88   51.96    40
# Sat      1778.40  260.40   219
# Sun      1627.16  247.39   216

# %% [markdown]
# - Saturday is a busy day and Friday is quite, It seems from the above table that on the weekend the restaurant is busier

# %%
tips.groupby('day').aggregate({'total_bill': 'sum',
                             'tip': 'sum'})# as  don't need size column sum
# Out:
#       total_bill     tip
# day
# Thur     1096.33  171.83
# Fri       325.88   51.96
# Sat      1778.40  260.40
# Sun      1627.16  247.39

# %% [markdown]
# - The day with most tips is Saturday ($260.40) and Friday is the day with least tips(51.96)

# %%
# sum of total bill and tips for each day grouped by sex and time
tips.groupby(['day','sex','time']).aggregate({'total_bill': 'sum',
                             'tip': 'sum'})# as  don't need size column sum
# Out:
#                     total_bill     tip
# day  sex    time
# Thur Male   Lunch       561.44   89.41
#      Female Lunch       516.11   79.42
#             Dinner       18.78    3.00
# Fri  Male   Lunch        34.16    5.70
#             Dinner      164.41   21.23
#      Female Lunch        55.76   10.98
#             Dinner       71.55   14.05
# Sat  Male   Dinner     1227.35  181.95
#      Female Dinner      551.05   78.45
# Sun  Male   Dinner     1269.46  186.78
#      Female Dinner      357.70   60.61

# %% [markdown]
# By looking at the table above it feels like the resturant opens only for dinner on weekend or the person who records the data worked on evenings on weekend. It looks that Friday dinner is very quite.

# %% [markdown]
# ### Busy & quite days

# %%
print(tips['day'].value_counts())# the number of rows for each day
sns.countplot(x='day' ,data=tips)#countplot for days
plt.show()
# Out:
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: day, dtype: int64

# %% [markdown]
# #### This shows that Friday is quite day and Saturday is busy

# %% [markdown]
# ### number of people served on each day

# %%
print(tips.groupby(by=['day'])['size'].sum())# the number of people served on each day
# Out:
# day
# Thur    152
# Fri      40
# Sat     219
# Sun     216
# Name: size, dtype: int64

# %% [markdown]
# ### dataset grouped by size of group on each day

# %%
#countplot for days with hue of group size
sns.countplot(x='day' ,hue='size',data=tips)
plt.show()

# %% [markdown]
# - It is apparent from the plot that, mostly people come in group of 2 on each day

# %%
sns.distplot(tips['size'])

# %% [markdown]
# ###   The tip as Percentage of bill

# %%
# Sum of total bill and sum of tips
print("Total Bill:  ",tips['total_bill'].sum())
print("Total Tips:  %.2f" %tips['tip'].sum())
# https://stackoverflow.com/questions/455612/limiting-floats-to-two-decimal-points
#percentage of tip
print("Percentage of Tips:  %.2f %%" %(tips['tip'].sum()/tips['total_bill'].sum()*100))
# Out:
# Total Bill:   4827.77
# Total Tips:  731.58
# Percentage of Tips:  15.15 %

# %% [markdown]
# -  tips are around 15% of the total_bill

# %% [markdown]
# # 2. Regression
# Linear Regression use to predict the value of a variable on the base of value of another variable when there is linear trend. We want to use the total bill amount to predict the tip amount so explanatory variable is bill and response variable is the amount of tip.
# Linear regression is a basic and commonly used type of predictive analysis.
# ## Analyse the relationship between total bill and tips
# for regression analysis first step is to visualise the data in scatter plot where independent variable is plotted along x-axis and dependent variable along y-axis

# %% [markdown]
# ### Scatter Plot
# A scatter plot is a two-dimensional data visualization that uses dots to represent the values obtained for two different variables - one plotted along the x-axis and the other plotted along the y-axis. scatter plots are powerful data visualization tools. these are also used to show if there is any connection between groups of data. If there is a strong connection or correlation, a ‘line of best fit’ can be drawn.

# %%
sns.scatterplot(x='total_bill',y='tip',data = tips)

# %% [markdown]
# In this plot we can see mostly total_bill is between 10–30 than the tip will be mostly above 2.scatter plot show there is a relationship between total_bill and tip. We can add the third variable in the above scatter graph.

# %%
sns.relplot(x='total_bill',y='tip',hue = 'smoker',data = tips) # same scatter plot with smoker hue

# %% [markdown]
# The above plot shows the highest bill and tip that is paid by smokers. These plots are very useful.

# %% [markdown]
# ## Regression Plot

# %% [markdown]
# The regression plots in seaborn are primarily intended to add a visual guide that helps to emphasize patterns in a dataset during exploratory data analysis. Regression plots creates a regression line between 2 parameters and helps to visualize their linear relationships.

# %% [markdown]
# There are two main functions in Seaborn to visualize a linear relationship determined through regression. These functions are regplot() and lmplot().
#
# __regplot__
# accepts the x and y variables in a variety of formats including simple numpy arrays, pandas Series objects, or as references to variables in a pandas DataFrame
#
# __Lmplot__
# has data as a required parameter and the x and y variables must be specified as strings. This data format is called “long-form” data

# %%
sns.set_style('whitegrid') #sns.set_style() is used to have a grid in the background instead of a default white background.

sns.regplot(x='total_bill',y='tip', data= tips)
# x and y parameters provide values for the x and y axes
# data parameter speciy source of data
plt.show()

# %% [markdown]
# The regression plot above shows that there is a linear relationship between tip and total bill

# %%
#Regression plots in seaborn can be easily implemented with the help of the lmplot() function. 
#lmplot() can be understood as a function that basically creates a linear model plot.
#lmplot() makes a very simple linear regression plot.It creates a scatter plot with a linear fit on top of it.
sns.lmplot(x='total_bill',y='tip', data= tips)
plt.show()

# %% [markdown]
# The lmplot above shows that there is a linear relationship between tip and total bill.

# %%
sns.jointplot(x="total_bill", y="tip", data=tips, kind="reg");
# jointplot show regrssion line along with distribution plot

# %% [markdown]
# The joint plot shows the regression line along with distribution plot and from the above plot it obvious that there is a  positive relationship between tips and total bill data, the tip amount increases as the bill amount increases.
#
# **Correlation between  tip and total_bill**
#
# In general Correlation refers to how close two variables are to having a linear relationship with each other, so correlation is a measure of relationship between variables that is measured on a -1 to 1 scale.
#
# There are two key components of a correlation value:
# - magnitude – The larger the magnitude (closer to 1 or -1), the stronger the correlation
# - sign – If negative, there is an inverse correlation. If positive, there is a regular correlation.

# %%
#fining the correlation in total_bill and tip
# source: https://stackoverflow.com/a/42580124
tips['total_bill'].corr(tips['tip'])
# Out:
# 0.6757341092113646

# %% [markdown]
# correlation value of 0.67 shows there is a strong relationship between total_bill and tip

# %%
#add third variable in plot as hue
# hue = 'sex' get two regression lines one for males and other for females
sns.set_style('whitegrid') 
sns.lmplot(x ='total_bill', y ='tip', data = tips,  
           hue ='sex', markers =['>', '<']) 
plt.show()

# %% [markdown]
# You can see from the slope of the best fit line for males and females has a positive slope, which means the data shows that the tip amount increases as total bill increases.

# %%
sns.set_style('whitegrid') 
sns.lmplot(x ='total_bill', y ='tip', data = tips,  
           hue ='smoker', markers =['+', '*']) 
plt.show()

# %% [markdown]
# You can see from Linear regression that the slope of the line of best fit for non smokers are more positive than that for smokers (orange line is steeper than blue line),which means the data shows non smoker is consisten but for smoker the point are widly spread around the line of best fit

# %%
# here we use day as col that we can see regression line for each day seprately
sns.set_style('whitegrid') 
sns.lmplot(x='total_bill',y='tip', data= tips, col='day',aspect=.5)

# %% [markdown]
# You can see that the slope of the best fit line for all days it is positive,which means the data shows on every day tip value is positively related to total_bill. Tip increases as total_bill increases

# %%
sns.set_style('whitegrid') 
sns.lmplot(x='total_bill',y='tip', data= tips, col='size',col_wrap=3,height= 3)

# %% [markdown]
# You can see from regression line that the slope of the best fit line for all sizes, it is  is positive,which means the data shows for size (1,2,3,4) the tip value is more positively related to total_bill. Tip increase as total_bill increases in the group size (5,6) the best fit line is not as steep and looks a bit flat.

# %%
# here in this regression plot we include three variable 1 row 1 column and 1 as hue
sns.lmplot(x ='total_bill', y ='tip', data = tips,  
           col ='sex', row ='time', hue ='smoker')

# %% [markdown]
# the slope of the best fit line for non smoker males and females is more positive than for smokers, males and females,(orange line is steeper than blue line),which means the data shows that the non smokers give more on tip than smokers.

# %% [markdown]
# ## Linear Regression with Scikit-Learn
#
# Linear regression model basically finds the best value for the intercept and slope,which results in a line that best fits the data. scikit-learn package in python is use in machine learning.
# it provides simple and efficient tools for data mining and data analysis.

# %%
#import 
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LinearRegression
X = tips['total_bill'].values.reshape(-1,1)
Y = tips['tip'].values.reshape(-1,1)
# we split 80% of the data to the training set while 20% of the data to test set using below code.
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=0)
# to train our algorithm, import LinearRegression class, instantiate it, and call the fit() method along with our training data
lreg = LinearRegression()  
lreg.fit(X_train, Y_train) #training the algorithm
# linear regression model basically finds the best value for the intercept and slope,
# which results in a line that best fits the data
# To see the value of the intercept and slope calculated by the linear regression algorithm for our dataset,
#To retrieve the intercept:
print("Intercept Value: ", lreg.intercept_)
#For retrieving the slope:
print("Slope Value: ",lreg.coef_)

# we will use our test data and see how accurately our algorithm predicts the tips.
#To make predictions on the test data, execute the following script:

Y_pred = lreg.predict(X_test)
# Now compare the actual output values for X_test with the predicted values, execute the following script:
df = pd.DataFrame({'Actual': Y_test.flatten(), 'Predicted': Y_pred.flatten()})
df
# Out:
# Intercept Value:  [1.02854395]
# Slope Value:  [[0.0968534]]
#     Actual  Predicted
# 0     2.64   2.732195
# 1     3.76   2.799993
# 2     3.51   2.916217
# 3     1.00   1.730731
# 4     2.50   2.604349
# 5     1.00   1.585451
# 6     3.08   2.764157
# 7     5.65   3.288134
# 8     3.50   2.786433
# 9     3.68   4.384514
# 10    5.00   3.476998
# 11    4.29   3.470218
# 12    2.50   2.391271
# 13    2.00   2.287638
# 14    1.58   2.328317
# 15    5.60   3.972887
# 16    1.50   1.837270
# 17    3.00   2.384492
# 18    3.00   2.847451
# 19    4.00   3.265858
# 20    2.00   3.939957
# 21    4.08   3.054717
# 22    2.00   2.578198
# 23    1.96   2.485219
# 24    2.00   2.337033
# 25    2.50   2.616940
# 26    2.20   2.206281
# 27    4.20   3.914775
# 28    4.71   3.477966
# 29    2.23   2.555922
# 30    2.20   2.455195
# 31    2.52   2.237274
# 32    1.57   2.522023
# 33    1.61   2.054221
# 34    3.00   2.799993
# 35    2.61   2.325411
# 36    3.07   2.668272
# 37    2.00   2.029040
# 38    9.00   5.709469
# 39    3.00   2.576261
# 40    1.92   1.859546
# 41    1.80   2.232432
# 42    3.00   2.548174
# 43    5.14   3.919618
# 44    2.23   2.264393
# 45    3.50   2.672146
# 46    3.76   2.795150
# 47    3.92   3.118640
# 48    3.00   2.681832

# %%
# plot first 40  actual and pridected values of 
df1 = df.head(40)
df1.plot(kind='bar',figsize=(12,9))
plt.grid(which='major', linestyle='-', linewidth='0.5', color='green')
plt.grid(which='minor', linestyle=':', linewidth='0.5', color='black')
plt.show()

# %%
#Though our model is not very precise, the predicted tip values are close to the actual ones.
#Let's plot our straight line with the test data :
plt.scatter(X_test, Y_test,  color='gray')
plt.plot(X_test, Y_pred, color='red', linewidth=2)
plt.show()

# %% [markdown]
# Evaluate the performance of the algorithm
#
# This step is particularly important to compare how well different algorithms perform on a particular dataset. For regression algorithms, three evaluation metrics are commonly used:
#
# 1. Mean Absolute Error (MAE) is the mean of the absolute value of the errors.
# 2. Mean Squared Error (MSE) is the mean of the squared errors
# 3. Root Mean Squared Error (RMSE) is the square root of the mean of the squared errors.
#
# The Scikit-Learn library comes with pre-built functions that can be used to find out these values for us.
# Let’s find the values for these metrics using our test data.

# %%
import numpy as np
from sklearn import metrics
print('Mean Absolute Error:', metrics.mean_absolute_error(Y_test, Y_pred).round(2))  
print('Mean Squared Error:', metrics.mean_squared_error(Y_test, Y_pred).round(2))  
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(Y_test, Y_pred)).round(2))
# Explained variance score: 1 is perfect prediction
print('Variance score: %.2f' % metrics.r2_score(Y_test, Y_pred))
lreg.score(X_test,Y_test)
# Out:
# Mean Absolute Error: 0.66
# Mean Squared Error: 0.82
# Root Mean Squared Error: 0.91
# Variance score: 0.59
# 0.5906895098589039

# %% [markdown]
# the value of root mean squared error is 0.91, which is more than 10% of the mean value of the percentages of all the tip i.e. 2.998. This means that our algorithm was not very accurate but can still make reasonably good predictions.
# source:https://towardsdatascience.com/a-beginners-guide-to-linear-regression-in-python-with-scikit-learn-83a8f7ae2b4f
#
# Regression also gives you an R squared value, which for this graph is 0.59. This number tells us how good our model is.
# The values range from 0 to 1, with 0 being a terrible model and 1 being a perfect model. Its mean, 0.59 is a fairly decent model so we can be still make reasonably good predictions.

# %% [markdown]
# # 3. The Relationship Between the Variables within the Dataset

# %% [markdown]
# Pair plot to show the relationship between the variables within the dataset

# %%
#ref:https://www.youtube.com/watch?v=GcXcSZ0gQps
sns.pairplot(data=tips, hue='sex')
plt.show()

# %%
#  correlation between tip and size
tips['tip'].corr(tips['size'])
# Out:
# 0.48929877523035714

# %%
# correlation between group size and total_bill
tips['total_bill'].corr(tips['size'])
# Out:
# 0.5983151309049012

# %% [markdown]
# ### Does tipping behaviour change on different days of the week?

# %%
df=tips.groupby('day').sum() # sum per day
df.drop('size',inplace=True,axis=1) # sum of size column is not relevant
df['percent'] = (df['tip']/df['total_bill']*100).round(2) # add percents
print(df)
# Out:
#       total_bill     tip  percent
# day
# Thur     1096.33  171.83    15.67
# Fri       325.88   51.96    15.94
# Sat      1778.40  260.40    14.64
# Sun      1627.16  247.39    15.20

# %% [markdown]
# If we look at the percentage there is not any huge difference, the highest on Friday is 15.94% and the lowest is on Saturday 14.64%

# %%
#catplot to show total_bill and tips on each day
f, axes = plt.subplots(1, 2, sharey= False, figsize=(10, 6))

sns.catplot(x="day", y="tip", data=tips, ax=axes[0])
#source: https://github.com/mwaskom/seaborn/issues/1514 to close empty graph
plt.close(2) # to close empty graph 
sns.catplot(x="day", y="total_bill", data=tips, ax=axes[1])
plt.close(2)# to close empty graphs in end

# %% [markdown]
# from the plots we can see that the maximum bill and the maximum tip data point is on Staurday.
# The data points distribution for tip and bill looks related

# %% [markdown]
# ### Do smokers tip differently than non-smokers?

# %%
# who eats more (and tips more)? smokers or non smokers?
df=tips.groupby('smoker').sum()#sum of smoker and nonsmoker
df['percent'] = (df['tip']/df['total_bill']*100).round(2) #add percent
print(df)# print
# Out:
#         total_bill     tip  size  percent
# smoker
# Yes        1930.34  279.81   224    14.50
# No         2897.43  451.77   403    15.59

# %% [markdown]
# it seems that on average non-smokers pay more tip than smokers. but there is not a huge difference

# %% [markdown]
# ###  Does the gender of the bill payer make a difference to the tip

# %%
df=tips.groupby('sex').sum()#sum of males and females numerical columns
df['percent'] = (df['tip']/df['total_bill']*100).round(2) #add percent column
print(df)# print
# Out:
#         total_bill     tip  size  percent
# sex
# Male       3256.82  485.07   413    14.89
# Female     1570.95  246.51   214    15.69

# %% [markdown]
# by looking at the percentage it seems that female pay slightly more tip than male

# %% [markdown]
# ## Which group sizes have higher density in dataset?

# %%
sns.relplot(x='total_bill',y='tip',hue='sex',col='size',data=tips,col_wrap=3, height= 3) #relplot

# %% [markdown]
# by looking at the plot it is obvious that group size 2,3 and 4 have high density. there are highest entries are for group size 2.

# %% [markdown]
# ## Does the size of the group effect the tip?

# %%
sns.set(style='darkgrid')
df= tips.groupby(['day','size']).sum()# group by day and size
df['percent'] = (df['tip']/df['total_bill']*100).round(2)
df = df.dropna() # drop null rows
print(df)
# Out:
#            total_bill     tip  percent
# day  size
# Thur 1          10.07    1.83    18.17
#      2         727.53  117.24    16.11
#      3          76.64   10.77    14.05
#      4         149.75   21.09    14.08
#      5          41.19    5.00    12.14
#      6          91.15   15.90    17.44
# Fri  1           8.58    1.92    22.38
#      2         261.15   42.31    16.20
#      3          15.98    3.00    18.77
#      4          40.17    4.73    11.77
# Sat  1          10.32    2.00    19.38
#      2         892.37  133.43    14.95
#      3         459.17   68.36    14.89
#      4         388.39   53.61    13.80
#      5          28.15    3.00    10.66
# Sun  2         684.84  109.86    16.04
#      3         332.76   46.81    14.07
#      4         480.39   73.58    15.32
#      5          81.00   12.14    14.99
#      6          48.17    5.00    10.38

# %% [markdown]
# from the above table it is obvious that the group size 1 and 2 give a higher tip (percentage of tip to total bill)

# %%
#sns.set(style='darkgrid')
df= tips.groupby(['size']).sum()# group size
df['percent'] = (df['tip']/df['total_bill']*100).round(2)
df = df.dropna() # drop null rows
print(df)
# Out:
#       total_bill     tip  percent
# size
# 1          28.97    5.75    19.85
# 2        2565.89  402.84    15.70
# 3         884.55  128.94    14.58
# 4        1058.70  153.01    14.45
# 5         150.34   20.14    13.40
# 6         139.32   20.90    15.00

# %% [markdown]
# The group size may effect the tip percentage as we see above size 5 is paying the least tip percentage and size 1 is paying the highest tip percentage

# %%
#barplot
sns.catplot(x='day',y='tip',hue='size',kind='swarm',data=tips)
plt.show()

# %% [markdown]
# as you can see in this graph the tip amount paid by bigger groups is big. but  previously we look at percentage of the tip related to bill, big groups have large bills and the percentage they are paying is less, but as we look at amount it looks that waiter earn more if seving bigger group

# %%
sns.catplot(x= 'size',y ='tip',data= tips , kind='bar')# the tip paid by bigger groups is more

# %%
sns.regplot(x='size',y='tip', data= tips)

# %% [markdown]
# This graph shows the trend that the amount of tip increse as the size of the group increase. but when we look at the percentage previously we see that the tip percentage to the total bill decrease.  from waiter's percpective he pobably get more tip when serving a big group but it involves more work as well.

# %% [markdown]
# ## Does tipping behaviour change at differing times(lunch, dinner)?

# %%
df=tips.groupby(['time']).sum()#sum of lunch  and dinner
df['percent'] = (df['tip']/df['total_bill']*100).round(2) #add percent
df.drop('size',inplace=True,axis=1)#drop size column
df=df.dropna()
print(df)# print
# Out:
#         total_bill     tip  percent
# time
# Lunch      1167.47  185.51    15.89
# Dinner     3660.30  546.07    14.92

# %% [markdown]
# There is a lower tip percentage at dinner but when we look at the histogram below it shows the waiter collects more tips at dinner.

# %%
g = sns.FacetGrid(tips, col="time" )
g = g.map(plt.hist, "tip",color="r")

# %%
df=tips.groupby(['day','time']).sum()#sum of lunch and dinner group by day
df['percent'] = (df['tip']/df['total_bill']*100).round(2) #add percent
df.drop('size',inplace=True,axis=1)#drop size column
df=df.dropna()
print(df)# print
# Out:
#              total_bill     tip  percent
# day  time
# Thur Lunch      1077.55  168.83    15.67
#      Dinner       18.78    3.00    15.97
# Fri  Lunch        89.92   16.68    18.55
#      Dinner      235.96   35.28    14.95
# Sat  Dinner     1778.40  260.40    14.64
# Sun  Dinner     1627.16  247.39    15.20

# %% [markdown]
# The tip percentage is lower on the weekend.

# %% [markdown]
# Here it seems from the above table that dinner has a lower tip percentage than lunch

# %% [markdown]
# #### Box plot
# A box plot (or box-and-whisker plot) shows the distribution of quantitative data in a way that facilitates comparisons between variables or across levels of a categorical variable. It can give all the stats provided in dataset .describe in a single plot. If the dataset is too large and the range of value is too big then it shows some values as outliers based on an inter-quartile function.
# <p align="center"><img src="images/boxplot.PNG"> </p>

# %%
sns.set(style="whitegrid")
sns.catplot(x = 'day',y = 'tip',data = tips, kind = 'box')
sns.swarmplot(x='day',y='tip',hue='time',data=tips,)
plt.show()

# %%
# http://seaborn.pydata.org/introduction.html#figure-level-and-axes-level-functions
g = sns.catplot(x="tip", y="day", hue="time",
                height=4, aspect=1.5,
                kind="box", legend=False, data=tips);

# %%
# http://seaborn.pydata.org/introduction.html#figure-level-and-axes-level-functions
g = sns.catplot(x="total_bill", y="day", hue="time",
                height=4, aspect=1.5,
                kind="box", legend=False, data=tips);
g.add_legend(title="Meal")
g.set_axis_labels("Total bill ", "")
g.set(xlim=(0, 60), yticklabels=["Thursday", "Friday", "Saturday", "Sunday"])
g.despine(trim=True)
g.fig.set_size_inches(6.5, 4)
g.ax.set_xticks([5, 15, 25, 35, 45, 55], minor=True);
plt.setp(g.ax.get_yticklabels(), rotation=30);

# %% [markdown]
# -

# %% [markdown]
# ## Total bill with respect to the time of day and gender

# %%
#multivarate graph total bill with respect to the time of the day and sex
g = sns.FacetGrid(tips, col="time",  row="sex" )
g = g.map(plt.hist, "total_bill",color="g")

# %% [markdown]
# We can see that the average amount of total_bill for females is always less than the males.

# %% [markdown]
# ### Point plots
# A point plot represents an estimate of central tendency for a numeric variable by the position of scatter plot points and provides some indication of the uncertainty around that estimate using error bars. Point plot shows only mean values and error rate surrounding those mean values. They are not very much informative but are easy to find the change in a variable based on different categories.

# %%
sns.catplot(x="day", y="total_bill", hue="sex", kind="point", data=tips);

# %% [markdown]
# - This plot shows changes in total_bill according to days for males and females.
# - The total_bill is increasing for male’s steadyly from Thursday to Sunday
# - while it decreases on Friday for females and increase on Saturday and remains mostly constant on Sunday.

# %% [markdown]
# ### Total bill with respect to time of day and smokers

# %%
#FacetGrid
#total bill with respect to the time of the day and smoker or non smoker
g = sns.FacetGrid(tips, col="time",  row="smoker")
g = g.map(plt.hist, "total_bill") #reference https://seaborn.pydata.org/generated/seaborn.FacetGrid.html

# %% [markdown]
# ### Proportion of Males and Females who paid the bill
# As it is obvious from the following graph that the male's percentage is greater than females.

# %%
#proportion of males and females who pay bill
gender=tips['sex'].value_counts()
plt.pie(gender,labels= ['Male','Female'], autopct='%1.1f%%', shadow= False)
plt.show()
#source:https://matplotlib.org/3.1.1/gallery/pie_and_polar_charts/pie_features.html

# %% [markdown]
# ### Comparison of total_bill paid by male and females

# %%
# Mean value of total bill and tip and size group by sex
print('Mean of total bill and tip and size group by sex \n',tips.groupby(['sex']).mean())
sns.set(style="whitegrid")
sns.catplot(x= 'day',y = 'total_bill',data= tips, kind= 'box',hue ='sex')
plt.show()
# Out:
# Mean of total bill and tip and size group by sex
#          total_bill       tip      size
# sex
# Male     20.744076  3.089618  2.630573
# Female   18.056897  2.833448  2.459770

# %% [markdown]
# - We can infer from the above plot that the amount of total_bill is higher on weekends than weekdays.
# - The average bill amount paid by females is mostly lower than males

# %%
sns.catplot(x= 'sex',y = 'total_bill',data= tips, kind= 'swarm')

# %% [markdown]
# - We can see that most of the total_bill are concentrated between 10 and 25 irrespective of the gender
# - the highest amount of bill in dataset is paid by male
# - the lowest bill in dataset is paid by female

# %% [markdown]
# ### Comparison of tip paid by male and femals
# Average tip paid by female and males do not have a huge difference and the average tip paid is between 2 to 4 dollars

# %%
sns.catplot(x= 'day',y = 'tip',data= tips, kind= 'box',hue ='sex')

# %%
sns.catplot(x= 'sex',y = 'tip',data= tips, kind= 'swarm')

# %% [markdown]
#  - We can see that most of the tips are concentrated between 2 and 4 irrespective of the gender.
#  - the highest tip $10 is paid by male

# %% [markdown]
# ### Total bill and Tip per day

# %%
#adapted from source: http://seaborn.pydata.org/introduction.html#figure-level-and-axes-level-functions
f, axes = plt.subplots(1, 2, sharey=True, figsize=(10, 6))
sns.boxplot(x="day", y="tip", data=tips, ax=axes[0])
sns.scatterplot(x="total_bill", y="tip", hue="day", data=tips, ax=axes[1]);

# %% [markdown]
# ### Total bill and amount of Tip per day per gender

# %%
g = sns.catplot(x="sex", y="total_bill", col="day",
                 data=tips, kind="violin", height=4, aspect=.6);

# %%
g = sns.catplot(x="sex", y="tip", col="day",
                 data=tips, kind="violin", height=4, aspect=.6);

# %% [markdown]
# The average amout of tips paid by both males and females are nearly same.

# %%
sns.set(style="whitegrid")
sns.catplot(x = 'day',y = 'total_bill',data = tips, kind = 'box')
sns.swarmplot(x='day',y='total_bill',data=tips, color ='black')
plt.show()

# %% [markdown]
# From the above boxplot we can see that the amount of total_bill is higher on weekends than weekdays.

# %%
sns.catplot(x= 'day',y = 'total_bill',data= tips, kind= 'boxen',hue ='sex')

# %%
sns.catplot(x= 'day',y = 'tip',data= tips, kind= 'boxen',hue ='sex')

# %%
sns.set(style="ticks")
g = sns.catplot(x= 'day',y = 'total_bill',data= tips, kind= 'violin')
sns.swarmplot(x= 'day',y = 'total_bill',data= tips,color = 'k', ax=g.ax)

# %% [markdown]
# ### How different gender's  bill and tip on each day

# %%
#sns.catplot(x= 'day',y = 'total_bill',data= tips, kind= 'swarm', hue='sex')
f, axes = plt.subplots(1, 2, sharey= False, figsize=(14, 6))
sns.catplot(x= 'day',y = 'tip',data= tips, kind= 'swarm', hue='sex',ax=axes[0])
plt.close(2)
sns.catplot(x= 'day',y = 'total_bill',data= tips, kind= 'swarm', hue='sex',ax=axes[1])
plt.close(2)
plt.show()

# %% [markdown]
# ### Does group size effect the bill and  tip

# %%
sns.pairplot(data=tips, x_vars=["total_bill", "size"], y_vars=["tip"],
             height=5, aspect=.8, kind="reg");

# %% [markdown]
# As it is clear from the regression lines in both graphs that tip has positive linear relationship with both total_bill and size of group(party)

# %%
#swarm plot of total_bill and tip grouped by days with hue=size
f, axes = plt.subplots(1, 2, sharey= False, figsize=(14, 6))
sns.catplot(x= 'day',y = 'tip',data= tips, kind= 'swarm', hue='size',ax=axes[0])
plt.close(2)
sns.catplot(x= 'day',y = 'total_bill',data= tips, kind= 'swarm', hue='size',ax=axes[1])
plt.close(2)
plt.show()

# %%
# swarm plot of tip and total_bill of smoker and non smoker groups hue= sex
f, axes = plt.subplots(1, 2, sharey= False, figsize=(14, 6))
sns.catplot(x= 'smoker',y = 'tip',data= tips, kind= 'swarm', hue='sex',ax=axes[0])
plt.close(2)
sns.catplot(x= 'smoker',y = 'total_bill',data= tips, kind= 'swarm', hue='sex',ax=axes[1])
plt.close(2)
plt.show()

# %% [markdown]
# # Conclusion
# From the analysis of data we find that
#  - Most tips were in range {2 to 4}.
#  - The total bill amount was mostly in range {10 to 25}
#  - The most common group size is 2.
#  - The number of males and females who paid the bill {males=157 and females=87 }can be determined in the data set but the amount of males and females that actually served is not clear because the party size tell the size of groups but not genders within group.
#  - It is the same with smokers and nonsmokers, as in a group of 6 there may only be one smoker or it may be a group of smokers. so we can not determine from the dataset how many smokers and non smokers were served in the restaurant.
#  - Depending on the day of the week there appears to be an increasing number of males paying the bill towards the weekend days
#  - It is clear from the regression analysis of the total bill and tips data. That there is a linear association between the amount of tip one earns and the customer's total bill. It is evident from the dataset that as a customer's total bill increases, the waiter's tip earnings increase as well.

# %% [markdown]
# # References

# %% [markdown]
# 1. Bryant, P. G. and Smith, M (1995) Practical Data Analysis: Case Studies in Business Statistics. Homewood, IL: Richard D. Irwin Publishing
# 2. Seaborn | Regression Plots available at  https://www.geeksforgeeks.org/seaborn-regression-plots/ accessed on 19/11/2019
# 3. PYTHON MACHINE LEARNING EXAMPLE – LINEAR REGRESSION availabe at https://devarea.com/python-machine-learning-example-linear-regression/#.Xda-Tsj7TIU accessed on 20/11/2019
# 4. What are Regression model and RMSD? available at https://www.codeastar.com/regression-model-rmsd/ accessed on 21/11/2019
# 5. A beginner’s guide to Linear Regression in Python with Scikit-Learn available at https://towardsdatascience.com/a-beginners-guide-to-linear-regression-in-python-with-scikit-learn-83a8f7ae2b4f accessed on 23/11/2019
# 6. Analyze the data through data visualization using Seaborn available at https://towardsdatascience.com/analyze-the-data-through-data-visualization-using-seaborn-255e1cd3948e accessed on 26/11/2019
# 7. STAT 503 Case Study 1: Restaurant Tipping available at https://dicook.public.iastate.edu/stat503/05/cs-tips2.pdf accessed on 27/11/2019

# %% [markdown]
# #### The End
